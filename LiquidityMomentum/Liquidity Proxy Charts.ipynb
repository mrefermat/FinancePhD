# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

import pylab
sns.set(font_scale=3)
pylab.rcParams['figure.figsize'] = (24, 18)

# %%
x=pd.read_csv('FHT.csv',index_col=0)
print x.T.to_latex()
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &   Equities &  Commodities &  Currencies &  Fixed Income \\
# \midrule
# Mean               &   0.016696 &     0.020271 &    0.007648 &      0.001766 \\
# Standard Deviation &   0.007945 &     0.004568 &    0.003265 &      0.000867 \\
# Skew               &   2.719278 &     2.074751 &    2.287401 &      1.320959 \\
# Kurtosis           &  12.546713 &     9.802079 &    9.251399 &      2.400806 \\
# \bottomrule
# \end{tabular}

# %%
y=pd.read_csv('amihud.csv',index_col=0)
print y.T.to_latex()
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  Commodities &    Equities &  Currencies &  Fixed Income \\
# \midrule
# Mean               &  2892.796273 &  124.833453 &  172.022897 &      1.032817 \\
# Standard Deviation &  1606.473446 &  138.943591 &  271.236341 &      0.836522 \\
# Skew               &     0.000000 &    0.000000 &    0.000000 &      0.000000 \\
# Kurtosis           &     0.000000 &    0.000000 &    0.000000 &      0.000000 \\
# Number of Markets  &    76.000000 &   29.000000 &    8.000000 &     32.000000 \\
# \bottomrule
# \end{tabular}

# %%
df=pd.DataFrame()
df['Amihud-Mean']=x.Mean
df['Amihud-Std']=x['Standard Deviation']
df['FHT-Mean']=y.Mean
df['FHT-Std']=y['Standard Deviation']

# %%
df[['FHT-Mean','Amihud-Mean']].plot(kind='bar',secondary_y='FHT-Mean')

# %%
print df.round(4).T.to_latex()
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  Equities &  Commodities &  Currencies &  Fixed Income \\
# \midrule
# Amihud-Mean &    0.0167 &       0.0203 &      0.0076 &        0.0018 \\
# Amihud-Std  &    0.0079 &       0.0046 &      0.0033 &        0.0009 \\
# FHT-Mean    &  124.8335 &    2892.7963 &    172.0229 &        1.0328 \\
# FHT-Std     &  138.9436 &    1606.4734 &    271.2363 &        0.8365 \\
# \bottomrule
# \end{tabular}

# %%
x.plot()
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/pandas/core/indexes/base.py:1743: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return getitem(key)
