# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)

dir = '/Users/mrefermat/git/FinancePhD/Empirical Methods/'

file2 = 'measurestailrisk.xlsx'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tail_data = pd.read_excel(dir+file2,parse_dates=[[0,1]],index_col=0)

# %%
tail_data.describe()
# Out:
#        Hellinger Tail Risk 1  Hellinger Tail Risk 2  Kelly and Jiang
# count           1.053000e+03            1053.000000      1053.000000
# mean           -1.264157e-15               0.000339        -0.026455
# std             1.000000e+00               1.006602         0.992050
# min            -9.429300e-01              -1.273626        -3.108887
# 25%            -5.892467e-01              -0.694104        -0.739384
# 50%            -3.244999e-01              -0.220850         0.035408
# 75%             1.424996e-01               0.402382         0.652802
# max             7.055882e+00               8.768204         3.858673

# %%
tail_data.skew()
# Out:
# Hellinger Tail Risk 1    2.916436
# Hellinger Tail Risk 2    2.528948
# Kelly and Jiang          0.082444
# dtype: float64

# %%
tail_data.kurtosis()
# Out:
# Hellinger Tail Risk 1    11.245636
# Hellinger Tail Risk 2    12.364590
# Kelly and Jiang           0.285536
# dtype: float64

# %%
tail_data.plot()

# %%
sns.violinplot(tail_data)
sns.pairplot(tail_data)

# %%
pd.ewma(tail_data,20).plot()

# %%
sns.corrplot(tail_data.diff())
