# %%
# %matplotlib inline
import seaborn
import quandl
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
token="Us3wFmXGgAj_1cUtHAAR"

import pylab
pylab.rcParams['figure.figsize'] = (16, 10)

# %%
treas = quandl.get("CHRIS/CME_TY1", authtoken=token)
stocks = quandl.get("CHRIS/CME_ES1", authtoken=token)

# %%
stocks.Last.plot()

# %%
treas.Last.plot()

# %%
df = pd.DataFrame()
df['ES']=stocks.Last
df['TY']=treas.Last

# %%
sns.corrplot(df.pct_change())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-313608343b56> in <module>()
# ----> 1 sns.corrplot(df.pct_change())
#
# AttributeError: 'module' object has no attribute 'corrplot'

# %%
(df.shift(250)-df).plot(secondary_y='TY')

# %%
X= pd.DataFrame()
X['T-1']=df.ES/df.ES.shift(20)-1
X['T-2']=df.ES/df.ES.shift(40)-1
X['T-3']=df.ES/df.ES.shift(60)-1
X['T-6']=df.ES/df.ES.shift(125)-1
X['T-12']=df.ES/df.ES.shift(250)-1
r= sm.OLS(df.pct_change()['1999':].ES,X['1999':]).fit()

# %%
print r.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     ES   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     41.50
# Date:                Sat, 29 Oct 2016   Prob (F-statistic):           6.61e-42
# Time:                        19:44:06   Log-Likelihood:                 13610.
# No. Observations:                4563   AIC:                        -2.721e+04
# Df Residuals:                    4558   BIC:                        -2.718e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# T-1            0.0554      0.005     10.431      0.000       0.045       0.066
# ...

# %%
X.dropna()
# Out:
#                  T-1       T-2       T-3       T-6      T-12
# Date
# 1998-08-28 -0.080365 -0.108161 -0.075839 -0.005537  0.105728
# 1998-08-31 -0.146085 -0.183879 -0.145512 -0.097636  0.042896
# 1998-09-01 -0.068901 -0.143102 -0.106944 -0.051233  0.101322
# 1998-09-02 -0.090200 -0.157850 -0.109213 -0.069484  0.072511
# 1998-09-03 -0.098124 -0.156217 -0.098124 -0.077445  0.069143
# 1998-09-04 -0.107787 -0.167306 -0.113053 -0.089277  0.031415
# 1998-09-07 -0.088006 -0.154452 -0.076977 -0.072230  0.048890
# 1998-09-08 -0.044258 -0.135300 -0.058081 -0.050231  0.082015
# 1998-09-09 -0.079092 -0.151278 -0.096085 -0.072286  0.045005
# 1998-09-10 -0.096632 -0.184012 -0.121130 -0.104536  0.006210
# 1998-09-11 -0.047440 -0.151287 -0.084424 -0.069511  0.054054
# 1998-09-14 -0.050715 -0.137411 -0.077509 -0.058743  0.078575
# 1998-09-15 -0.063503 -0.116418 -0.083389 -0.064349  0.094559
# 1998-09-16 -0.049864 -0.106183 -0.085116 -0.062402  0.099397
# ...
