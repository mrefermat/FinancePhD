# %%
# %matplotlib inline
import seaborn
from pymongo import MongoClient
from datetime import datetime
from arctic import Arctic
import quandl
import pandas as pd
token="Us3wFmXGgAj_1cUtHAAR"


import pylab
pylab.rcParams['figure.figsize'] = (12, 8)

# %%
client = MongoClient()
db = client.test
collection = db.SP

# %%
db.SP
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'test'), u'SP')

# %%
df= pd.DataFrame()
df['ES']=quandl.get("CHRIS/CME_ES1", authtoken=token).Last

# %%
df.ES.plot()

# %%
# Using Arctic database to store
store = Arctic('localhost')

# Create the library - defaults to VersionStore
store.initialize_library('NASDAQ')

# Access the library
library = store['NASDAQ']

# Load some data - maybe from Quandl
aapl = quandl.get("WIKI/AAPL")

# Store the data in the library
library.write('AAPL', aapl, metadata={'source': 'Quandl'})
# Out:
# WARNING:arctic.store.version_store:Library created, but couldn't enable sharding: no such command: 'enablesharding', bad cmd: '{ enablesharding: "arctic" }'. This is OK if you're not 'admin'
# VersionedItem(symbol=AAPL,library=arctic.NASDAQ,data=<type 'NoneType'>,version=2,metadata={'source': 'Quandl'}

# %%
# Reading the data
item = library.read('AAPL')
aapl_test = item.data
metadata_test = item.metadata

# %%
pd.DataFrame(aapl.Low)
# Out:
#                  Low
# Date
# 1980-12-12   28.7500
# 1980-12-15   27.2500
# 1980-12-16   25.2500
# 1980-12-17   25.8700
# 1980-12-18   26.6300
# 1980-12-19   28.2500
# 1980-12-22   29.6300
# 1980-12-23   30.8800
# 1980-12-24   32.5000
# 1980-12-26   35.5000
# 1980-12-29   36.0000
# 1980-12-30   35.1200
# 1980-12-31   34.1300
# 1981-01-02   34.5000
# 1981-01-05   33.7500
# 1981-01-06   32.2500
# 1981-01-07   30.8800
# 1981-01-08   30.2500
# 1981-01-09   31.8800
# 1981-01-12   31.6200
# 1981-01-13   30.5000
# 1981-01-14   30.6300
# 1981-01-15   31.2500
# 1981-01-16   31.0000
# 1981-01-19   32.8700
# 1981-01-20   31.8800
# 1981-01-21   32.5000
# 1981-01-22   32.8700
# 1981-01-23   32.7500
# 1981-01-26   32.2500
# ...              ...
# 2016-12-07  109.1600
# 2016-12-08  110.6000
# 2016-12-09  112.3100
# 2016-12-12  112.4900
# 2016-12-13  113.7500
# 2016-12-14  114.9800
# 2016-12-15  115.2300
# 2016-12-16  115.6450
# 2016-12-19  115.7500
# 2016-12-20  116.6800
# 2016-12-21  116.7800
# 2016-12-22  115.6400
# 2016-12-23  115.5900
# 2016-12-27  116.4900
# 2016-12-28  116.2000
# 2016-12-29  116.4000
# 2016-12-30  115.4300
# 2017-01-03  114.7600
# 2017-01-04  115.7500
# 2017-01-05  115.8100
# 2017-01-06  116.4700
# 2017-01-09  117.9400
# 2017-01-10  118.3000
# 2017-01-11  118.6000
# 2017-01-12  118.2100
# 2017-01-13  118.8100
# 2017-01-17  118.2200
# 2017-01-18  119.7100
# 2017-01-19  119.3700
# 2017-01-20  119.7346
#
# [9105 rows x 1 columns]

# %%
aapl_test.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1980-12-12   0.427992   0.429779  0.427992    0.427992  117258400.0
# 1980-12-15   0.407597   0.407597  0.405662    0.405662   43971200.0
# 1980-12-16   0.377675   0.377675  0.375889    0.375889   26432000.0
# 1980-12-17   0.385119   0.387054  0.385119    0.385119   21610400.0
# 1980-12-18   0.396432   0.398219  0.396432    0.396432   18362400.0
