# %%
# %matplotlib inline
import seaborn
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
token="Us3wFmXGgAj_1cUtHAAR"

import pylab
pylab.rcParams['figure.figsize'] = (12, 8)
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
df=quandl.get("CHRIS/CME_ES1")[['Last','Volume']]

# %%
df.plot(secondary_y='Last')

# %%
df2=pd.DataFrame()
df2['Price']=df.resample(rule='m',how='last').Last.pct_change().dropna()
df2['Volume']=df.Volume.dropna().resample(rule='m',how='mean')
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).last()
#   from IPython.kernel.zmq import kernelapp as app
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   app.launch_new_instance()

# %%
df2['2007':].dropna().plot(kind='scatter',x='Price',y='Volume')

# %%
sns.lmplot(data=df2['2007':],x='Price',y='Volume')

# %%
s=df2.Price
s[0:]='Non-Crisis'
s['9-1-2008':'9-1-2009']='Global Financial Crisis'
df2['Price']=df.resample(rule='m',how='last').Last.pct_change().dropna()
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).last()

# %%
sns.lmplot(data=df2['2007':],x='Price',y='Volume',hue='Period',palette="Set1")

# %%
df2.plot(kind='scatter')
