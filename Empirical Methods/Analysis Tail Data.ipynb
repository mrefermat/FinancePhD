# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)

dir = '/Users/mrefermat/git/FinancePhD/Empirical Methods/'

file2 = 'measurestailrisk.xlsx'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tail_data = pd.read_excel(dir+file2,parse_dates=[[0,1,2]],index_col=0)

# %%
tail_data.mean()
# Out:
# Hellinger Tail Risk 1   -1.264157e-15
# Hellinger Tail Risk 2    3.389642e-04
# Kelly and Jiang         -2.645548e-02
# dtype: float64

# %%
tail_data.plot()

# %%
sns.violinplot(tail_data)
sns.pairplot(tail_data)

# %%
sns.corrplot(tail_data)
