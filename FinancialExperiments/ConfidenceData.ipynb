# %%
# %matplotlib inline
import math
import pandas as pd
import quandl as q
from tsmom_model import *
import numpy as np
import statsmodels.tsa.vector_ar.var_model as VAR
from datetime import datetime
token="Us3wFmXGgAj_1cUtHAAR"

import pylab
sns.set(font_scale=3)
pylab.rcParams['figure.figsize'] = (24, 18)

# %%
data=q.get('YALE/US_CONF_INDEX_CRASH_INST',token=token)

# %%
data.head()
# Out:
#             Index Value  Standard Error
# Date
# 1989-10-31        36.99            4.00
# 1990-04-30        25.76            3.81
# 1990-10-31        18.25            3.30
# 1991-04-30        31.58            4.03
# 1991-10-31        37.18            3.87

# %%
data.plot(secondary_y='Standard Error')

# %%
bw=pd.read_excel('http://people.stern.nyu.edu/jwurgler/data/Investor_Sentiment_Data_v23_POST.xlsx',
             header=21).set_index('year')

# %%
bw.head()
# Out:
#      SENT^  SENT SENT^(old) SENT(old) pdnd nipo ripo cefd         s turn  \
# year
# 1927      .    .          .         .    .    .    .    .  0.265512    .
# 1928      .    .          .         .    .    .    .    .  0.497429    .
# 1929      .    .          .         .    .    .    .    .  0.720593    .
# 1930      .    .          .         .    .    .    .    .  0.307847    .
# 1931      .    .          .         .    .    .    .    .  0.144665    .
#
#      ldturn  Unnamed: 12 nipo2
# year
# 1927      .          NaN     .
# 1928      .          NaN     .
# 1929      .          NaN     .
# 1930      .          NaN     .
# 1931      .          NaN     .

# %%
bw.columns
# Out:
# Index([     u'SENT^ ',        u'SENT',  u'SENT^(old)',   u'SENT(old)',
#               u'pdnd',        u'nipo',        u'ripo',        u'cefd',
#                  u's',        u'turn',      u'ldturn', u'Unnamed: 12',
#              u'nipo2'],
#       dtype='object')

# %%
bw.replace('.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-3190250452cb> in <module>()
# ----> 1 bw.replace('.')
#
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    4492             if isinstance(to_replace, (tuple, list)):
#    4493                 return _single_replace(self, to_replace, method, inplace,
# -> 4494                                        limit)
#    4495
#    4496             if not is_dict_like(to_replace):
#
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _single_replace(self, to_replace, method, inplace, limit)
#      74     if self.ndim != 1:
#      75         raise TypeError('cannot replace {0} with method {1} on a {2}'
# ---> 76                         .format(to_replace, method, type(self).__name__))
# ...
