# %%
# %matplotlib inline
import seaborn
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import math
token="Us3wFmXGgAj_1cUtHAAR"
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
import pylab
sns.set(font_scale=2)
pylab.rcParams['figure.figsize'] = (24, 18)

# %%
names=['ENI','NOKIA','SAN','SAF','BNP','ACA']
df=pd.DataFrame()
for i in names:
    df[i]=quandl.get('EURONEXT/'+i,token=token).Last

# %%
data_pct=df.pct_change()
data_pct.cumsum().plot()

# %%
sns.clustermap(data_pct.corr(),annot=True)

# %%
x=data_pct.corr()

# %%
# Average pairwise correlation
n=x.count().count()
total=x.abs().sum().sum()
(total-n)/(n*(n-1))

# %%
1./x.count().iloc[1]
# Out:
# 0.16666666666666666

# %%
corrM=pd.expanding_corr(data_pct,min_periods=250)
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.expanding_corr is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.expanding(min_periods=250).corr(other=<DataFrame>,pairwise=True)
#   """Entry point for launching an IPython kernel.

# %%
corrM=pd.expanding_corr(data_pct,min)

# %%
corrM['2016-01-03':]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-027f4b385460> in <module>()
# ----> 1 corrM['2016-01-03':]
#
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2125
#    2126         # see if we can slice the rows
# -> 2127         indexer = convert_to_index_sliceable(self, key)
#    2128         if indexer is not None:
#    2129             return self._getitem_slice(indexer)
#
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in convert_to_index_sliceable(obj, key)
#    1978     idx = obj.index
#    1979     if isinstance(key, slice):
# -> 1980         return idx._convert_slice_indexer(key, kind='getitem')
#    1981
#    1982     elif isinstance(key, compat.string_types):
#
# ...

# %%
for m in corrM.dropna().index:
    print corrM[m]
    break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-7df66baaec2d> in <module>()
#       1 for m in corrM.dropna().index:
# ----> 2     print corrM[m]
#       3     break
#
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
# Out:
# <function count>
