# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import pylab
sns.set(font_scale=3)
pylab.rcParams['figure.figsize'] = (24, 18)
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
x=np.random.RandomState().(size=10000)
sns.distplot(x)

# %%
d=np.random.RandomState().poisson(10,size=100000)

# %%
sns.distplot(d)

# %%
d
# Out:
# array([1, 1, 0, ..., 2, 1, 1])

# %%
rs=np.random.RandomState()

# %%
rs.multivariate_normal(np.array([2,4]),np.array([[1,.2][.2,1]]),100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-3ea65d7368e6> in <module>()
# ----> 1 rs.multivariate_normal(np.array([2,4]),np.array([[1,.2][.2,1]]),100)
#
# TypeError: list indices must be integers, not tuple

# %%
np.array([2,4])
# Out:
# array([2, 4])
