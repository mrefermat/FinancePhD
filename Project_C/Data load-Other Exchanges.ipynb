# %%
# %matplotlib inline
import quandl
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from marketdata import *
import math
from datetime import datetime
import statsmodels.api as sm
from arctic import Arctic
token="Us3wFmXGgAj_1cUtHAAR"

import pylab
sns.set(font_scale=3)
pylab.rcParams['figure.figsize'] = (24, 18)
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# F	January
# G	February
# H	March
# J	April
# K	May
# M	June
# N	July
# Q	August
# U	September
# V	October
# X	November
# Z	December

# %%
from arctic import Arctic
store = Arctic('localhost')
static_table = store['CHINA_STATIC']

# %%
mkts=static_table.read('Markets').data

# %%
mkts.exchange.unique()
# Out:
# array(['DCE', 'SHFE', 'CZCE', 'CFFEX'], dtype=object)

# %%
mkts[mkts.exchange=='CFFEX'].index
# Out:
# Index([u'IC', u'IF', u'IH', u'T', u'TF'], dtype='object', name=u'Ticker')

# %%
list_of_months = ['F','G','H','J','K','M','N','Q','U','V','X','Z']

# %% [markdown]
# # Load exchange

# %%
for exchange in mkts.exchange.unique():
    list_of_markets=mkts[mkts.exchange==exchange].index
    for mkt in list_of_markets:
        price, OI = quandl_load_data(mkt,exchange)
        intital_load(mkt,ticker,exchange,price,OI)
# Out:
# Missing G 2018
# Missing J 2018
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2009
# Missing K 2009
# Missing U 2009
# Missing H 2008
# Missing X 2008
# Missing N 2007
# Missing F 2018
# Missing H 2018
# Missing K 2018
# Missing N 2018
# Missing U 2018
# Missing X 2018
# Missing G 2017
# Missing M 2017
# Missing V 2017
# Missing J 2016
# Missing Z 2016
# Missing Q 2015
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2013
# Missing G 2012
# Missing J 2012
# Missing N 2012
# Missing X 2012
# Missing H 2011
# Missing U 2011
# Missing K 2010
# Missing F 2018
# Missing H 2018
# Missing K 2018
# Missing N 2018
# Missing U 2018
# Missing X 2018
# Missing G 2017
# Missing M 2017
# Missing V 2017
# Missing J 2016
# Missing Z 2016
# Missing Q 2015
# Missing G 2018
# Missing J 2018
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2014
# Missing H 2013
# Missing N 2013
# Missing X 2013
# Missing K 2012
# Missing U 2011
# Missing G 2018
# Missing J 2018
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2014
# Missing K 2014
# Missing U 2014
# Missing H 2013
# Missing X 2013
# Missing N 2012
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2012
# Missing G 2011
# Missing J 2011
# Missing N 2011
# Missing X 2011
# Missing H 2010
# Missing U 2010
# Missing K 2009
# Missing F 2018
# Missing H 2018
# Missing K 2018
# Missing N 2018
# Missing U 2018
# Missing X 2018
# Missing G 2017
# Missing M 2017
# Missing V 2017
# Missing J 2016
# Missing Z 2016
# Missing Q 2015
# Missing G 2018
# Missing J 2018
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2013
# Missing K 2013
# Missing H 2012
# Missing U 2012
# Missing N 2011
# Missing X 2010
# Missing G 2018
# Missing J 2018
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2012
# Missing K 2012
# Missing U 2012
# Missing H 2011
# Missing X 2011
# Missing N 2010
# Missing G 2018
# Missing J 2018
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2013
# Missing K 2013
# Missing H 2012
# Missing U 2012
# Missing N 2011
# Missing X 2010
# Missing G 2018
# Missing J 2018
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2013
# Missing H 2012
# Missing N 2012
# Missing X 2012
# Missing K 2011
# Missing U 2010
# Missing F 2018
# Missing H 2018
# Missing K 2018
# Missing N 2018
# Missing U 2018
# Missing X 2018
# Missing G 2017
# Missing M 2017
# Missing V 2017
# Missing J 2016
# Missing Z 2016
# Missing Q 2015
# Missing F 2018
# Missing H 2018
# Missing K 2018
# Missing N 2018
# Missing U 2018
# Missing X 2018
# Missing G 2017
# Missing M 2017
# Missing V 2017
# Missing J 2016
# Missing Z 2016
# Missing Q 2012
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2014
# Missing H 2014
# Missing K 2014
# Missing U 2014
# Missing G 2013
# Missing N 2013
# Missing J 2012
# Missing X 2011
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2014
# Missing H 2014
# Missing K 2014
# Missing U 2014
# Missing G 2013
# Missing N 2013
# Missing J 2012
# Missing X 2011
# Missing G 2018
# Missing J 2018
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2009
# Missing K 2009
# Missing U 2009
# Missing H 2008
# Missing X 2008
# Missing N 2007
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2009
# Missing H 2009
# Missing K 2009
# Missing U 2009
# Missing G 2008
# Missing N 2008
# Missing J 2007
# Missing X 2006
# Missing F 2018
# Missing H 2018
# Missing K 2018
# Missing N 2018
# Missing U 2018
# Missing X 2018
# Missing G 2017
# Missing M 2017
# Missing V 2017
# Missing Q 2016
# Missing J 2013
# Missing Z 2012
# Missing G 2018
# Missing J 2018
# Missing M 2018
# Missing Q 2018
# Missing V 2018
# Missing Z 2018
# Missing F 2013
# Missing K 2013
# Missing H 2012
# Missing U 2012
# Missing N 2011
# Missing X 2010
# Missing F 2018
# Missing H 2018
# Missing K 2018
# Missing N 2018
# Missing U 2018
# Missing X 2018
# Missing G 2017
# Missing M 2017
# Missing V 2017
# Missing J 2016
# Missing Z 2016
# Missing Q 2015
# Missing F 2018
# Missing H 2018
# Missing K 2018
# Missing N 2018
# Missing U 2018
# Missing X 2018
# Missing G 2017
# Missing M 2017
# Missing V 2017
# Missing J 2016
# Missing Z 2016
# Missing Q 2015
# Missing N 2018
# Missing U 2018
# Missing X 2018
# Missing F 2016
# Missing H 2016
# Missing G 2015
# Missing K 2015
# Missing Q 2015
# Missing Z 2015
# Missing J 2014
# Missing V 2014
# Missing M 2013
