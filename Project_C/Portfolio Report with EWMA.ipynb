# %%
# %matplotlib inline
from marketdata import *
from model import *
from analytics import *
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math
from datetime import datetime

import pylab
sns.set(font_scale=3)
pylab.rcParams['figure.figsize'] = (24, 18)
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# # Load data
#
# Try clean up markets with 100% close out values

# %%
def remove_inf(pnl):
    return pnl.replace(np.inf,0).replace(-np.inf,0)

# %%
list_of_markets=get_market_list()

# %%
df=pd.DataFrame()
for m in list_of_markets:
    try:
        df[m]=get_timeseries(m)
    except:
        print m
# Out:
# RU
# S

# %%
mkts=df.T[df.count().sort_values()!=0].index
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
pos=ewma_mom_daily(df[mkts],10,30)
pnl=calc_pnl_wc(pos,df[mkts])
scaling_factor=calc_scaling_factor(pnl)
portfolio= remove_inf(pnl).mean(axis=1).dropna()*scaling_factor

# %%
calc_Sharpe(pnl,250).dropna().sort_values().plot(kind='bar')

# %%
portfolio.cumsum().plot()

# %%
pnl_with_lookbacks=pd.DataFrame()
for l in range(10,130,10):
    pos=ewma_mom_daily(df[mkts],l,3*l)
    pnl=calc_pnl_wc(pos,df[mkts])
    scaling_factor=calc_scaling_factor(pnl)
    pnl_with_lookbacks[str(l)]= remove_inf(pnl).mean(axis=1).dropna()*scaling_factor
# Out:
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=20).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=60).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:26: FutureWarning: pd.ewm_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=120,adjust=True,com=60).std(bias=False)
#   return (signal/pd.ewmstd(signal,lookback,min_periods=lookback*2))
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=90).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:26: FutureWarning: pd.ewm_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=180,adjust=True,com=90).std(bias=False)
#   return (signal/pd.ewmstd(signal,lookback,min_periods=lookback*2))
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=40).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=120).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:26: FutureWarning: pd.ewm_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=240,adjust=True,com=120).std(bias=False)
#   return (signal/pd.ewmstd(signal,lookback,min_periods=lookback*2))
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=50).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=150).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:26: FutureWarning: pd.ewm_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=300,adjust=True,com=150).std(bias=False)
#   return (signal/pd.ewmstd(signal,lookback,min_periods=lookback*2))
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=180).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:26: FutureWarning: pd.ewm_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=360,adjust=True,com=180).std(bias=False)
#   return (signal/pd.ewmstd(signal,lookback,min_periods=lookback*2))
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=70).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=210).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:26: FutureWarning: pd.ewm_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=420,adjust=True,com=210).std(bias=False)
#   return (signal/pd.ewmstd(signal,lookback,min_periods=lookback*2))
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=80).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=240).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:26: FutureWarning: pd.ewm_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=480,adjust=True,com=240).std(bias=False)
#   return (signal/pd.ewmstd(signal,lookback,min_periods=lookback*2))
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=270).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:26: FutureWarning: pd.ewm_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=540,adjust=True,com=270).std(bias=False)
#   return (signal/pd.ewmstd(signal,lookback,min_periods=lookback*2))
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=100).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=300).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:26: FutureWarning: pd.ewm_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=600,adjust=True,com=300).std(bias=False)
#   return (signal/pd.ewmstd(signal,lookback,min_periods=lookback*2))
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=110).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:18: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=0,adjust=True,com=330).mean()
#   signal=signal=pd.ewma(data,short_lookback)-pd.ewma(data,long_lookback)
# model.py:26: FutureWarning: pd.ewm_std is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(ignore_na=False,min_periods=660,adjust=True,com=330).std(bias=False)
#   return (signal/pd.ewmstd(signal,lookback,min_periods=lookback*2))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-5a37007a4776> in <module>()
#       3     pos=ewma_mom_daily(df[mkts],l,3*l)
#       4     pnl=calc_pnl_wc(pos,df[mkts])
# ----> 5     scaling_factor=calc_scaling_factor(pnl)
#       6     pnl_with_lookbacks[str(l)]= remove_inf(pnl).mean(axis=1).dropna()*scaling_factor
#
# /Users/mrefermat/git/FinancePhD/Project_C/analytics.pyc in calc_scaling_factor(pnl, vol_target)
#      31         w=np.array([1/float(no_mkts)]*no_mkts)
#      32         mkt_list=row[1].dropna().index
# ---> 33         Sig = Sigma_all[mkt_list].T[mkt_list]
#      34         vol_ach=np.sqrt(np.dot(np.dot(w.T,Sig.as_matrix()),w))*16
#      35         SF.append(vol_target/vol_ach)
#
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1989         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1990             # either boolean or fancy integer index
# -> 1991             return self._getitem_array(key)
#    1992         elif isinstance(key, DataFrame):
#    1993             return self._getitem_frame(key)
#
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2033             return self.take(indexer, axis=0, convert=False)
#    2034         else:
# -> 2035             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2036             return self.take(indexer, axis=1, convert=True)
#    2037
#
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1212                 mask = check == -1
#    1213                 if mask.any():
# -> 1214                     raise KeyError('%s not in index' % objarr[mask])
#    1215
#    1216                 return _values_from_object(indexer)
#
# KeyError: "Index([u'LR'], dtype='object') not in index"

# %%
pnl_with_lookbacks['2007':].cumsum().plot(colormap='jet')

# %%
calc_Sharpe(pnl_with_lookbacks['2007':],250).plot(kind='bar',title='Sharpe Ratio')

# %%
(pnl_with_lookbacks.std()*16).plot(kind='bar',title='Volatility')

# %%
sns.heatmap(pnl_with_lookbacks.corr())
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Drawdown analysis

# %%
temp=(pnl_with_lookbacks.resample(rule='m',how='sum')+1).cumprod()
(temp/pd.rolling_max(temp,1000000,min_periods=1)).plot(colormap='jet')
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()
#   if __name__ == '__main__':
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: FutureWarning: pd.rolling_max is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(min_periods=1,window=1000000,center=False).max()
#   from IPython.kernel.zmq import kernelapp as app

# %%
temp2=(1-(temp/pd.rolling_max(temp,1000000,min_periods=1)).min())
temp2.plot(kind='bar',colormap='jet',title='Max Drawdown')
# Out:
# /Users/mrefermat/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: FutureWarning: pd.rolling_max is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(min_periods=1,window=1000000,center=False).max()
#   if __name__ == '__main__':
