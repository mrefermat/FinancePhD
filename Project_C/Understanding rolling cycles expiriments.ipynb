# %%
# %matplotlib inline
import seaborn as sns
import quandl
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math
from tsmom_model import *
from datetime import datetime
import statsmodels.api as sm
token="Us3wFmXGgAj_1cUtHAAR"

import pylab
sns.set(font_scale=3)
pylab.rcParams['figure.figsize'] = (24, 18)

# %% [markdown]
# F	January
# G	February
# H	March
# J	April
# K	May
# M	June
# N	July
# Q	August
# U	September
# V	October
# X	November
# Z	December

# %%
list_of_months = ['F','G','H','J','K','M','N','Q','U','V','X','Z']

# %%
# Iron Ore 
list_of_months=['F','K','U']
ddf={}
for y in range(2010,2018,1):
    for m in list_of_months:
        try:
            ddf[m + str(y)[2:]]=quandl.get('DCE/I' + m + str(y),authtoken=token)[['Close','Volume','Turnover','Open Interest']]
        except:
            print 'Missing '+m + ' '+ str(y)

# %%
f, ax = plt.subplots()
for k in ddf.keys():
    if ddf[k].Volume.max() > 1:
        ddf[k]['Open Interest'].plot(ax=ax)

# %%
f, ax = plt.subplots()
for k in ddf.keys():
    if ddf[k].Volume.max() > 1:
        ddf[k]['Volume'].plot(ax=ax)
