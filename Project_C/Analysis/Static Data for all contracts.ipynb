# %%
import pandas as pd

# %%
dict={'abbrev_symbol': {'A': 'DY1105',
  'AG': 'BY1508',
  'AL': 'L0403',
  'AU': 'HJ1207',
  'B': 'null',
  'BB': 'JHB1502',
  'BU': 'SYLQ1504',
  'C': 'YM1309',
  'CF': 'MH0610',
  'CS': 'YMDF1609',
  'CU': 'T0906',
  'ER': 'ZCD1009',
  'FB': 'null',
  'FG': 'null',
  'FU': 'RLY1310',
  'GN': 'LD0309',
  'HC': 'rzjb1612',
  'I': 'TKS1604',
  'IC': 'ZZ1610',
  'IF': 'HS1010',
  'IH': 'SZ1612',
  'J': 'JT1601',
  'JD': 'JD1410',
  'JM': 'JM1605',
  'JR': 'JDG1503',
  'L': 'JYX1509',
  'LR': 'WXD1605',
  'M': 'DP1405',
  'MA': 'null',
  'ME': 'JC1206',
  'NI': 'N1603',
  'OI': 'CZY1605',
  'P': 'null',
  'PB': 'Q1111',
  'PM': 'PM1611',
  'PP': 'JBX1503',
  'RB': 'LWG1405',
  'RI': 'ZXD1503',
  'RM': 'CZP1609',
  'RO': 'CZY0803',
  'RS': 'YCZ1309',
  'RU': 'null',
  'S': 'DD9911',
  'SF': 'GT1604',
  'SM': 'MG1609',
  'SN': 'X1702',
  'SR': 'null',
  'T': 'CZ1512',
  'TA': 'PTA1206',
  'TC': 'DLM1602',
  'TF': 'GZ1406',
  'V': 'JLYX1101',
  'WH': 'QM1703',
  'WR': 'XC1408',
  'WS': 'QM0609',
  'WT': 'YM0003',
  'Y': 'DY0711',
  'ZC': 'DLM1611',
  'ZN': 'X0812'},
 'contract_multiplier': {'A': 10.0,
  'AG': 15.0,
  'AL': 5.0,
  'AU': 1000.0,
  'B': 10.0,
  'BB': 500.0,
  'BU': 10.0,
  'C': 10.0,
  'CF': 5.0,
  'CS': 10.0,
  'CU': 5.0,
  'ER': 10.0,
  'FB': 500.0,
  'FG': 20.0,
  'FU': 50.0,
  'GN': 10.0,
  'HC': 10.0,
  'I': 100.0,
  'IC': 200.0,
  'IF': 300.0,
  'IH': 300.0,
  'J': 100.0,
  'JD': 10.0,
  'JM': 60.0,
  'JR': 20.0,
  'L': 5.0,
  'LR': 20.0,
  'M': 10.0,
  'MA': 10.0,
  'ME': 50.0,
  'NI': 1.0,
  'OI': 10.0,
  'P': 10.0,
  'PB': 25.0,
  'PM': 50.0,
  'PP': 5.0,
  'RB': 10.0,
  'RI': 20.0,
  'RM': 10.0,
  'RO': 5.0,
  'RS': 10.0,
  'RU': 10.0,
  'S': 10.0,
  'SF': 5.0,
  'SM': 5.0,
  'SN': 1.0,
  'SR': 10.0,
  'T': 10000.0,
  'TA': 5.0,
  'TC': 200.0,
  'TF': 10000.0,
  'V': 5.0,
  'WH': 20.0,
  'WR': 10.0,
  'WS': 10.0,
  'WT': 10.0,
  'Y': 10.0,
  'ZC': 100.0,
  'ZN': 5.0},
 'de_listed_date': {'A': '2011-05-16',
  'AG': '2015-08-17',
  'AL': '2004-03-15',
  'AU': '2012-07-16',
  'B': '2017-07-14',
  'BB': '2015-02-13',
  'BU': '2015-04-15',
  'C': '2013-09-13',
  'CF': '2006-10-20',
  'CS': '2016-09-14',
  'CU': '2009-06-15',
  'ER': '2010-09-17',
  'FB': '2017-06-14',
  'FG': '2017-06-14',
  'FU': '2013-09-30',
  'GN': '2003-09-22',
  'HC': '2016-12-15',
  'I': '2016-04-15',
  'IC': '2016-10-21',
  'IF': '2010-10-15',
  'IH': '2016-12-16',
  'J': '2016-01-15',
  'JD': '2014-10-21',
  'JM': '2016-05-16',
  'JR': '2015-03-13',
  'L': '2015-09-16',
  'LR': '2016-05-16',
  'M': '2014-05-16',
  'MA': '2017-09-14',
  'ME': '2012-06-14',
  'NI': '2016-03-15',
  'OI': '2016-05-16',
  'P': '2018-01-17',
  'PB': '2011-11-15',
  'PM': '2016-11-14',
  'PP': '2015-03-13',
  'RB': '2014-05-15',
  'RI': '2015-03-13',
  'RM': '2016-09-14',
  'RO': '2008-03-14',
  'RS': '2013-09-13',
  'RU': '2017-10-16',
  'S': '1999-11-12',
  'SF': '2016-04-15',
  'SM': '2016-09-14',
  'SN': '2017-02-15',
  'SR': '2018-07-13',
  'T': '2015-12-11',
  'TA': '2012-06-14',
  'TC': '2016-02-05',
  'TF': '2014-06-13',
  'V': '2011-01-17',
  'WH': '2017-03-14',
  'WR': '2014-08-15',
  'WS': '2006-09-21',
  'WT': '2000-03-23',
  'Y': '2007-11-14',
  'ZC': '2016-11-07',
  'ZN': '2008-12-15'},
 'exchange': {'A': 'DCE',
  'AG': 'SHFE',
  'AL': 'SHFE',
  'AU': 'SHFE',
  'B': 'DCE',
  'BB': 'DCE',
  'BU': 'SHFE',
  'C': 'DCE',
  'CF': 'CZCE',
  'CS': 'DCE',
  'CU': 'SHFE',
  'ER': 'CZCE',
  'FB': 'DCE',
  'FG': 'CZCE',
  'FU': 'SHFE',
  'GN': 'CZCE',
  'HC': 'SHFE',
  'I': 'DCE',
  'IC': 'CFFEX',
  'IF': 'CFFEX',
  'IH': 'CFFEX',
  'J': 'DCE',
  'JD': 'DCE',
  'JM': 'DCE',
  'JR': 'CZCE',
  'L': 'DCE',
  'LR': 'CZCE',
  'M': 'DCE',
  'MA': 'CZCE',
  'ME': 'CZCE',
  'NI': 'SHFE',
  'OI': 'CZCE',
  'P': 'DCE',
  'PB': 'SHFE',
  'PM': 'CZCE',
  'PP': 'DCE',
  'RB': 'SHFE',
  'RI': 'CZCE',
  'RM': 'CZCE',
  'RO': 'CZCE',
  'RS': 'CZCE',
  'RU': 'SHFE',
  'S': 'DCE',
  'SF': 'CZCE',
  'SM': 'CZCE',
  'SN': 'SHFE',
  'SR': 'CZCE',
  'T': 'CFFEX',
  'TA': 'CZCE',
  'TC': 'CZCE',
  'TF': 'CFFEX',
  'V': 'DCE',
  'WH': 'CZCE',
  'WR': 'SHFE',
  'WS': 'CZCE',
  'WT': 'CZCE',
  'Y': 'DCE',
  'ZC': 'CZCE',
  'ZN': 'SHFE'},
 'listed_date': {'A': '2009-11-16',
  'AG': '2014-08-18',
  'AL': '2003-08-22',
  'AU': '2011-07-18',
  'B': '2016-07-15',
  'BB': '2014-02-21',
  'BU': '2014-10-16',
  'C': '2012-09-17',
  'CF': '2005-11-01',
  'CS': '2015-09-17',
  'CU': '2008-06-17',
  'ER': '2009-09-23',
  'FB': '2016-06-17',
  'FG': '2016-06-17',
  'FU': '2012-10-08',
  'GN': '2002-10-08',
  'HC': '2015-12-16',
  'I': '2015-04-16',
  'IC': '2016-08-22',
  'IF': '2010-08-23',
  'IH': '2016-04-18',
  'J': '2015-01-19',
  'JD': '2013-11-08',
  'JM': '2015-05-18',
  'JR': '2014-03-17',
  'L': '2014-09-16',
  'LR': '2015-05-18',
  'M': '2013-05-16',
  'MA': '2016-09-19',
  'ME': '2011-10-28',
  'NI': '2015-03-27',
  'OI': '2015-05-18',
  'P': '2017-01-17',
  'PB': '2011-03-24',
  'PM': '2015-11-16',
  'PP': '2014-03-17',
  'RB': '2013-05-16',
  'RI': '2014-03-17',
  'RM': '2015-09-17',
  'RO': '2007-06-08',
  'RS': '2012-12-28',
  'RU': '2016-10-18',
  'S': '1999-01-04',
  'SF': '2015-04-16',
  'SM': '2015-09-17',
  'SN': '2016-02-16',
  'SR': '2017-01-17',
  'T': '2015-03-20',
  'TA': '2011-06-16',
  'TC': '2015-02-09',
  'TF': '2013-09-06',
  'V': '2010-01-18',
  'WH': '2016-03-15',
  'WR': '2013-08-16',
  'WS': '2005-10-10',
  'WT': '1999-04-01',
  'Y': '2006-11-15',
  'ZC': '2015-11-09',
  'ZN': '2007-12-24'},
 'margin_rate': {'A': 0.050000000000000003,
  'AG': 0.040000000000000001,
  'AL': 0.050000000000000003,
  'AU': 0.070000000000000007,
  'B': 0.050000000000000003,
  'BB': 0.050000000000000003,
  'BU': 0.040000000000000001,
  'C': 0.050000000000000003,
  'CF': 0.050000000000000003,
  'CS': 0.070000000000000007,
  'CU': 0.050000000000000003,
  'ER': 0.050000000000000003,
  'FB': 0.20000000000000001,
  'FG': 0.20000000000000001,
  'FU': 0.080000000000000002,
  'GN': 0.20000000000000001,
  'HC': 0.040000000000000001,
  'I': 0.070000000000000007,
  'IC': 0.40000000000000002,
  'IF': 0.14999999999999999,
  'IH': 0.40000000000000002,
  'J': 0.070000000000000007,
  'JD': 0.080000000000000002,
  'JM': 0.089999999999999997,
  'JR': 0.050000000000000003,
  'L': 0.050000000000000003,
  'LR': 0.050000000000000003,
  'M': 0.050000000000000003,
  'MA': 0.069999999999999993,
  'ME': 0.059999999999999998,
  'NI': 0.050000000000000003,
  'OI': 0.050000000000000003,
  'P': 0.069999999999999993,
  'PB': 0.080000000000000002,
  'PM': 0.050000000000000003,
  'PP': 0.050000000000000003,
  'RB': 0.070000000000000007,
  'RI': 0.050000000000000003,
  'RM': 0.050000000000000003,
  'RO': 0.050000000000000003,
  'RS': 0.050000000000000003,
  'RU': 0.089999999999999997,
  'S': 0.050000000000000003,
  'SF': 0.050000000000000003,
  'SM': 0.050000000000000003,
  'SN': 0.050000000000000003,
  'SR': 0.050000000000000003,
  'T': 0.02,
  'TA': 0.059999999999999998,
  'TC': 0.050000000000000003,
  'TF': 0.02,
  'V': 0.050000000000000003,
  'WH': 0.050000000000000003,
  'WR': 0.070000000000000007,
  'WS': 0.050000000000000003,
  'WT': 0.050000000000000003,
  'Y': 0.050000000000000003,
  'ZC': 0.050000000000000003,
  'ZN': 0.050000000000000003},
 'maturity_date': {'A': '2011-05-16',
  'AG': '2015-08-17',
  'AL': '2004-03-15',
  'AU': '2012-07-16',
  'B': '2017-07-14',
  'BB': '2015-02-13',
  'BU': '2015-04-15',
  'C': '2013-09-13',
  'CF': '2006-10-20',
  'CS': '2016-09-14',
  'CU': '2009-06-15',
  'ER': '2010-09-17',
  'FB': '2017-06-14',
  'FG': '2017-06-14',
  'FU': '2013-09-30',
  'GN': '2003-09-22',
  'HC': '2016-12-15',
  'I': '2016-04-15',
  'IC': '2016-10-21',
  'IF': '2010-10-15',
  'IH': '2016-12-16',
  'J': '2016-01-15',
  'JD': '2014-10-21',
  'JM': '2016-05-16',
  'JR': '2015-03-13',
  'L': '2015-09-16',
  'LR': '2016-05-16',
  'M': '2014-05-16',
  'MA': '2017-09-14',
  'ME': '2012-06-14',
  'NI': '2016-03-15',
  'OI': '2016-05-16',
  'P': '2018-01-17',
  'PB': '2011-11-15',
  'PM': '2016-11-14',
  'PP': '2015-03-13',
  'RB': '2014-05-15',
  'RI': '2015-03-13',
  'RM': '2016-09-14',
  'RO': '2008-03-14',
  'RS': '2013-09-13',
  'RU': '2017-10-16',
  'S': '1999-11-12',
  'SF': '2016-04-15',
  'SM': '2016-09-14',
  'SN': '2017-02-15',
  'SR': '2018-07-13',
  'T': '2015-12-11',
  'TA': '2012-06-14',
  'TC': '2016-02-05',
  'TF': '2014-06-13',
  'V': '2011-01-17',
  'WH': '2017-03-14',
  'WR': '2014-08-15',
  'WS': '2006-09-21',
  'WT': '2000-03-23',
  'Y': '2007-11-14',
  'ZC': '2016-11-07',
  'ZN': '2008-12-15'},
 'order_book_id': {'A': 'A1105',
  'AG': 'AG1508',
  'AL': 'AL0403',
  'AU': 'AU1207',
  'B': 'B1707',
  'BB': 'BB1502',
  'BU': 'BU1504',
  'C': 'C1309',
  'CF': 'CF0610',
  'CS': 'CS1609',
  'CU': 'CU0906',
  'ER': 'ER1009',
  'FB': 'FB1706',
  'FG': 'FG1706',
  'FU': 'FU1310',
  'GN': 'GN0309',
  'HC': 'HC1612',
  'I': 'I1604',
  'IC': 'IC1610',
  'IF': 'IF1010',
  'IH': 'IH1612',
  'J': 'J1601',
  'JD': 'JD1410',
  'JM': 'JM1605',
  'JR': 'JR1503',
  'L': 'L1509',
  'LR': 'LR1605',
  'M': 'M1405',
  'MA': 'MA1709',
  'ME': 'ME1206',
  'NI': 'NI1603',
  'OI': 'OI1605',
  'P': 'P1801',
  'PB': 'PB1111',
  'PM': 'PM1611',
  'PP': 'PP1503',
  'RB': 'RB1405',
  'RI': 'RI1503',
  'RM': 'RM1609',
  'RO': 'RO0803',
  'RS': 'RS1309',
  'RU': 'RU1710',
  'S': 'S9911',
  'SF': 'SF1604',
  'SM': 'SM1609',
  'SN': 'SN1702',
  'SR': 'SR1807',
  'T': 'T1512',
  'TA': 'TA1206',
  'TC': 'TC1602',
  'TF': 'TF1406',
  'V': 'V1101',
  'WH': 'WH1703',
  'WR': 'WR1408',
  'WS': 'WS0609',
  'WT': 'WT0003',
  'Y': 'Y0711',
  'ZC': 'ZC1611',
  'ZN': 'ZN0812'},
 'product': {'A': 'Commodity',
  'AG': 'Commodity',
  'AL': 'Commodity',
  'AU': 'Commodity',
  'B': 'Commodity',
  'BB': 'Commodity',
  'BU': 'Commodity',
  'C': 'Commodity',
  'CF': 'Commodity',
  'CS': 'Commodity',
  'CU': 'Commodity',
  'ER': 'Commodity',
  'FB': 'Commodity',
  'FG': 'Commodity',
  'FU': 'Commodity',
  'GN': 'Commodity',
  'HC': 'Commodity',
  'I': 'Commodity',
  'IC': 'Index',
  'IF': 'Index',
  'IH': 'Index',
  'J': 'Commodity',
  'JD': 'Commodity',
  'JM': 'Commodity',
  'JR': 'Commodity',
  'L': 'Commodity',
  'LR': 'Commodity',
  'M': 'Commodity',
  'MA': 'Commodity',
  'ME': 'Commodity',
  'NI': 'Commodity',
  'OI': 'Commodity',
  'P': 'Commodity',
  'PB': 'Commodity',
  'PM': 'Commodity',
  'PP': 'Commodity',
  'RB': 'Commodity',
  'RI': 'Commodity',
  'RM': 'Commodity',
  'RO': 'Commodity',
  'RS': 'Commodity',
  'RU': 'Commodity',
  'S': 'Commodity',
  'SF': 'Commodity',
  'SM': 'Commodity',
  'SN': 'Commodity',
  'SR': 'Commodity',
  'T': 'Government',
  'TA': 'Commodity',
  'TC': 'Commodity',
  'TF': 'Government',
  'V': 'Commodity',
  'WH': 'Commodity',
  'WR': 'Commodity',
  'WS': 'Commodity',
  'WT': 'Commodity',
  'Y': 'Commodity',
  'ZC': 'Commodity',
  'ZN': 'Commodity'},
 'round_lot': {'A': 1.0,
  'AG': 1.0,
  'AL': 1.0,
  'AU': 1.0,
  'B': 1.0,
  'BB': 1.0,
  'BU': 1.0,
  'C': 1.0,
  'CF': 1.0,
  'CS': 1.0,
  'CU': 1.0,
  'ER': 1.0,
  'FB': 1.0,
  'FG': 1.0,
  'FU': 1.0,
  'GN': 1.0,
  'HC': 1.0,
  'I': 1.0,
  'IC': 1.0,
  'IF': 1.0,
  'IH': 1.0,
  'J': 1.0,
  'JD': 1.0,
  'JM': 1.0,
  'JR': 1.0,
  'L': 1.0,
  'LR': 1.0,
  'M': 1.0,
  'MA': 1.0,
  'ME': 1.0,
  'NI': 1.0,
  'OI': 1.0,
  'P': 1.0,
  'PB': 1.0,
  'PM': 1.0,
  'PP': 1.0,
  'RB': 1.0,
  'RI': 1.0,
  'RM': 1.0,
  'RO': 1.0,
  'RS': 1.0,
  'RU': 1.0,
  'S': 1.0,
  'SF': 1.0,
  'SM': 1.0,
  'SN': 1.0,
  'SR': 1.0,
  'T': 1.0,
  'TA': 1.0,
  'TC': 1.0,
  'TF': 1.0,
  'V': 1.0,
  'WH': 1.0,
  'WR': 1.0,
  'WS': 1.0,
  'WT': 1.0,
  'Y': 1.0,
  'ZC': 1.0,
  'ZN': 1.0},
 'settlement_method': {'A': 'PhysicalSettlementRequired',
  'AG': 'PhysicalSettlementRequired',
  'AL': 'PhysicalSettlementRequired',
  'AU': 'PhysicalSettlementRequired',
  'B': 'UNKNOWN',
  'BB': 'PhysicalSettlementRequired',
  'BU': 'PhysicalSettlementRequired',
  'C': 'PhysicalSettlementRequired',
  'CF': 'PhysicalSettlementRequired',
  'CS': 'PhysicalSettlementRequired',
  'CU': 'PhysicalSettlementRequired',
  'ER': 'PhysicalSettlementRequired',
  'FB': 'UNKNOWN',
  'FG': 'UNKNOWN',
  'FU': 'PhysicalSettlementRequired',
  'GN': 'PhysicalSettlementRequired',
  'HC': 'PhysicalSettlementRequired',
  'I': 'PhysicalSettlementRequired',
  'IC': 'CashSettlementRequired',
  'IF': 'CashSettlementRequired',
  'IH': 'CashSettlementRequired',
  'J': 'PhysicalSettlementRequired',
  'JD': 'PhysicalSettlementRequired',
  'JM': 'PhysicalSettlementRequired',
  'JR': 'PhysicalSettlementRequired',
  'L': 'PhysicalSettlementRequired',
  'LR': 'PhysicalSettlementRequired',
  'M': 'PhysicalSettlementRequired',
  'MA': 'UNKNOWN',
  'ME': 'PhysicalSettlementRequired',
  'NI': 'PhysicalSettlementRequired',
  'OI': 'PhysicalSettlementRequired',
  'P': 'UNKNOWN',
  'PB': 'PhysicalSettlementRequired',
  'PM': 'PhysicalSettlementRequired',
  'PP': 'PhysicalSettlementRequired',
  'RB': 'PhysicalSettlementRequired',
  'RI': 'PhysicalSettlementRequired',
  'RM': 'PhysicalSettlementRequired',
  'RO': 'PhysicalSettlementRequired',
  'RS': 'PhysicalSettlementRequired',
  'RU': 'UNKNOWN',
  'S': 'UNKNOWN',
  'SF': 'PhysicalSettlementRequired',
  'SM': 'PhysicalSettlementRequired',
  'SN': 'PhysicalSettlementRequired',
  'SR': 'UNKNOWN',
  'T': 'PhysicalSettlementRequired',
  'TA': 'PhysicalSettlementRequired',
  'TC': 'PhysicalSettlementRequired',
  'TF': 'PhysicalSettlementRequired',
  'V': 'PhysicalSettlementRequired',
  'WH': 'PhysicalSettlementRequired',
  'WR': 'PhysicalSettlementRequired',
  'WS': 'PhysicalSettlementRequired',
  'WT': 'PhysicalSettlementRequired',
  'Y': 'PhysicalSettlementRequired',
  'ZC': 'PhysicalSettlementRequired',
  'ZN': 'PhysicalSettlementRequired'},
 'symbol': {'A': '豆一1105',
  'AG': '白银1508',
  'AL': '铝0403',
  'AU': '黄金1207',
  'B': '黄大豆2号1707',
  'BB': '胶合板1502',
  'BU': '石油沥青1504',
  'C': '玉米1309',
  'CF': '棉花0610',
  'CS': '玉米淀粉1609',
  'CU': '铜0906',
  'ER': '早籼稻1009',
  'FB': '中密度纤维板1706',
  'FG': '玻璃706',
  'FU': '燃料油1310',
  'GN': '绿豆0309',
  'HC': '热轧卷板1612',
  'I': '铁矿石1604',
  'IC': '中证1610',
  'IF': '沪深1010',
  'IH': '上证1612',
  'J': '焦炭1601',
  'JD': '鸡蛋1410',
  'JM': '焦煤1605',
  'JR': '粳稻谷1503',
  'L': '聚乙烯1509',
  'LR': '晚籼稻1605',
  'M': '豆粕1405',
  'MA': '甲醇709',
  'ME': '甲醇1206',
  'NI': '镍1603',
  'OI': '菜籽油1605',
  'P': '棕榈油1801',
  'PB': '铅1111',
  'PM': '普麦1611',
  'PP': '聚丙烯1503',
  'RB': '螺纹钢1405',
  'RI': '早籼稻1503',
  'RM': '菜籽粕1609',
  'RO': '菜籽油0803',
  'RS': '油菜籽1309',
  'RU': '天然橡胶1710',
  'S': '大豆9911',
  'SF': '硅铁1604',
  'SM': '锰硅1609',
  'SN': '锡1702',
  'SR': '白砂糖807',
  'T': '长债1512',
  'TA': 'PTA1206',
  'TC': '动力煤1602',
  'TF': '国债1406',
  'V': '聚氯乙烯1101',
  'WH': '强麦1703',
  'WR': '线材1408',
  'WS': '强麦0609',
  'WT': '硬麦0003',
  'Y': '豆油0711',
  'ZC': '动力煤1611',
  'ZN': '锌0812'},
 'trading_unit': {'A': '10',
  'AG': '15',
  'AL': '5',
  'AU': '1000',
  'B': 'null',
  'BB': '500',
  'BU': '10',
  'C': '10',
  'CF': '5',
  'CS': '10',
  'CU': '5',
  'ER': '10',
  'FB': 'null',
  'FG': 'null',
  'FU': '50',
  'GN': '10',
  'HC': '10',
  'I': '100',
  'IC': '手',
  'IF': '手',
  'IH': '手',
  'J': '100',
  'JD': '5',
  'JM': '60',
  'JR': '20',
  'L': '5',
  'LR': '20',
  'M': '10',
  'MA': 'null',
  'ME': '50',
  'NI': '1',
  'OI': '10',
  'P': 'null',
  'PB': '25',
  'PM': '50',
  'PP': '5',
  'RB': '10',
  'RI': '20',
  'RM': '10',
  'RO': '5',
  'RS': '10',
  'RU': 'null',
  'S': '10',
  'SF': '5',
  'SM': '5',
  'SN': '1',
  'SR': 'null',
  'T': '手',
  'TA': '5',
  'TC': '200',
  'TF': '手',
  'V': '5',
  'WH': '20',
  'WR': '10',
  'WS': '10',
  'WT': '10',
  'Y': '10',
  'ZC': '100',
  'ZN': '5'},
 'type': {'A': 'Future',
  'AG': 'Future',
  'AL': 'Future',
  'AU': 'Future',
  'B': 'Future',
  'BB': 'Future',
  'BU': 'Future',
  'C': 'Future',
  'CF': 'Future',
  'CS': 'Future',
  'CU': 'Future',
  'ER': 'Future',
  'FB': 'Future',
  'FG': 'Future',
  'FU': 'Future',
  'GN': 'Future',
  'HC': 'Future',
  'I': 'Future',
  'IC': 'Future',
  'IF': 'Future',
  'IH': 'Future',
  'J': 'Future',
  'JD': 'Future',
  'JM': 'Future',
  'JR': 'Future',
  'L': 'Future',
  'LR': 'Future',
  'M': 'Future',
  'MA': 'Future',
  'ME': 'Future',
  'NI': 'Future',
  'OI': 'Future',
  'P': 'Future',
  'PB': 'Future',
  'PM': 'Future',
  'PP': 'Future',
  'RB': 'Future',
  'RI': 'Future',
  'RM': 'Future',
  'RO': 'Future',
  'RS': 'Future',
  'RU': 'Future',
  'S': 'Future',
  'SF': 'Future',
  'SM': 'Future',
  'SN': 'Future',
  'SR': 'Future',
  'T': 'Future',
  'TA': 'Future',
  'TC': 'Future',
  'TF': 'Future',
  'V': 'Future',
  'WH': 'Future',
  'WR': 'Future',
  'WS': 'Future',
  'WT': 'Future',
  'Y': 'Future',
  'ZC': 'Future',
  'ZN': 'Future'},
 'underlying_order_book_id': {'A': 'null',
  'AG': 'null',
  'AL': 'null',
  'AU': 'null',
  'B': 'null',
  'BB': 'null',
  'BU': 'null',
  'C': 'null',
  'CF': 'null',
  'CS': 'null',
  'CU': 'null',
  'ER': 'null',
  'FB': 'null',
  'FG': 'null',
  'FU': 'null',
  'GN': 'null',
  'HC': 'null',
  'I': 'null',
  'IC': '000905.XSHG',
  'IF': '000300.XSHG',
  'IH': '000016.XSHG',
  'J': 'null',
  'JD': 'null',
  'JM': 'null',
  'JR': 'null',
  'L': 'null',
  'LR': 'null',
  'M': 'null',
  'MA': 'null',
  'ME': 'null',
  'NI': 'null',
  'OI': 'null',
  'P': 'null',
  'PB': 'null',
  'PM': 'null',
  'PP': 'null',
  'RB': 'null',
  'RI': 'null',
  'RM': 'null',
  'RO': 'null',
  'RS': 'null',
  'RU': 'null',
  'S': 'null',
  'SF': 'null',
  'SM': 'null',
  'SN': 'null',
  'SR': 'null',
  'T': 'null',
  'TA': 'null',
  'TC': 'null',
  'TF': 'null',
  'V': 'null',
  'WH': 'null',
  'WR': 'null',
  'WS': 'null',
  'WT': 'null',
  'Y': 'null',
  'ZC': 'null',
  'ZN': 'null'}}

# %%
static=pd.DataFrame().from_dict(dict)[cols]
s=pd.Series()
for row in static.iterrows():
    s[row[0]]=row[1].symbol[:-4]
static.symbol = s
static['Ticker']=static.index.to_series()
static['Description']=pd.read_csv('descrip.csv').set_index('Ticker').Description
static=static.set_index('Ticker')

# %%
static.head()
# Out:
#         contract_multiplier exchange  margin_rate    product  \
# Ticker
# A                      10.0      DCE         0.05  Commodity
# AG                     15.0     SHFE         0.04  Commodity
# AL                      5.0     SHFE         0.05  Commodity
# AU                   1000.0     SHFE         0.07  Commodity
# B                      10.0      DCE         0.05  Commodity
#
#                  settlement_method symbol trading_unit           Description
# Ticker
# A       PhysicalSettlementRequired     豆一           10               Soybean
# AG      PhysicalSettlementRequired     白银           15                Silver
# AL      PhysicalSettlementRequired      铝            5              Aluminum
# AU      PhysicalSettlementRequired     黄金         1000                  Gold
# B                          UNKNOWN  黄大豆2号         null  Yellow Soybean No. 2

# %%
from arctic import Arctic
store = Arctic('localhost')
static_table = store['CHINA_STATIC']

# %%
static_table.write('Markets',static)
# Out:
# VersionedItem(symbol=Markets,library=arctic.CHINA_STATIC,data=<type 'NoneType'>,version=1,metadata=None
